# %% [markdown]
# # Matplotlib : Graphiques de Base

# %% [markdown]
#  Pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Graphiques simples

# %%
X = np.linspace(0, 2, 10)
y = X**2

plt.plot(X, y)
plt.show()

# %%
plt.scatter(X, y)
plt.show()

# %% [markdown]
# # Styles Graphiques
# Il existe beaucoup de styles a ajouter aux graphiques. Voici les plus importants a retenir :
#
# c : couleur de la ligne
# lw : epaisseur de la ligne (pour les graphiques plot)
# ls : style de la ligne (pour les graphiques plot)
# size : taille du point (pour les graphiques scatter)
# marker : style de points (pour les graphiques scatter)
# alpha : transparence du graphique

# %%
plt.plot(X, y, c='red', lw=4, ls='--', alpha=0.8)
plt.show()

# %% [markdown]
# # Cycle de vie d'une figure

# %% [markdown]
# # Pour créer des figures proprements, on doit suivre le cycle de vie suivant :
#
# plt.figure(figsize())
# plt.plot()
# Extras (titre, axes, legendes)
# plt.show()

# %%
X = np.linspace(0, 2, 10)

plt.figure() # Création d'une figure
plt.plot(X, X**2, label='quadratique') # premiere courbe
plt.plot(X, X**3, label='cubique') # deuxieme courbe
# Extra information
plt.title('figure 1') # titre
plt.xlabel('axe x') # axes
plt.ylabel('axe y') # axes
plt.legend() # legend

plt.savefig('figure.png') # sauvegarde la figure dans le repertoire de travail
plt.show() # affiche la figure

# %% [markdown]
# # Subplots
# Les subplots sont un autre éléments a ajouter pour créer plusieurs graphiques sur une meme figure

# %%
plt.subplot(2, 1, 1)
plt.plot(X, y, c='red')
plt.subplot(2, 1, 2)
plt.plot(X, y, c='blue')

# %% [markdown]
# # Méthode orientée objet

# %%
fig, ax = plt.subplots(2, 1, sharex=True) # partage le meme axe pour les subplots
ax[0].plot(X, y)
ax[1].plot(X, np.sin(X))
plt.show()

# %% [markdown]
# # Exercice et Solution

# %% [markdown]
# Créez une fonction "graphique" qui permet de tracer sur une seule et meme figure une série de graphiques issue d'un dictionnaire contenant plusieurs datasets :

# %%
def graphique(dataset):
  # Votre code ici...
  return

# Voici le dataset utilisé
dataset = {f"experience{i}": np.random.randn(100) for i in range(4)}

dataset
# Out:
# {'experience0': array([ 1.0335748 , -0.1866035 ,  1.18209864, -2.64545696,  1.58338417,
#          2.34454548,  0.33721409, -0.76500901, -1.41385351,  1.60121322,
#          0.30533265, -0.40241159,  0.1305595 ,  2.24548057, -1.04644122,
#         -0.06619757, -1.02235897, -0.62743513,  0.80958917, -0.1835852 ,
#          0.88438832,  0.30481158,  0.82577146,  1.19676875, -1.68994293,
#          0.12271055, -2.04770456,  0.29706847,  0.11155489,  1.05536531,
#         -1.2180505 , -0.18691324,  0.26937161,  0.30697931,  1.35300646,
#         -0.4875718 ,  0.51615061,  1.30562078,  1.32266223,  0.58811797,
#         -2.16280234, -0.30756483, -0.10411248, -1.56722514,  0.90575963,
#         -1.40119398,  0.26441743,  0.44280054, -1.63534387,  2.19032868,
#         -1.27935923, -0.50635702,  1.83885335, -3.28281907,  0.77793474,
#         -0.50741242, -0.8148852 ,  0.31865271, -0.95465945, -1.68202789,
#          0.18631439,  0.10933319, -0.53978017,  1.61471186,  1.64970655,
#         -1.07956603,  1.84155027, -0.38697432, -2.14948422, -0.85803031,
#         -1.1829075 , -0.32904833, -0.68413102, -0.81753195, -0.98105526,
#          0.13190655, -0.10606849,  0.93011635,  1.93760818, -0.85115303,
#          1.22683853, -1.52336151,  0.46240816, -0.03138827, -0.00953111,
#         -2.19864426,  0.12128502, -1.49074235, -1.48672475, -2.07484345,
#         -1.04836455,  0.57055237,  0.29413946,  1.28634354,  0.98864483,
#         -3.27516478,  0.71352261, -0.35558756,  0.28870917, -0.30563185,
#         -0.85084038,  0.08148196, -0.1453946 ,  0.50189372, -0.7054399 ,
#         -0.94991778,  1.64778872, -0.23903432, -0.05630433,  0.03949655,
#         -1.45290956, -1.25077516,  0.44469979, -0.38976921, -0.12248359]),
#  'experience3': array([ 1.01730519, -0.76897304, -1.54791361, -0.47250754, -0.98864785,
#         -1.72221736,  2.12359121,  0.40984235, -0.24935884,  1.99013467,
#          0.29017644,  0.68885678,  1.68224311, -0.26015484,  0.2412586 ,
#          0.08601647, -0.70759687, -0.35345809,  1.06487668,  2.27211684,
#          0.14629003,  0.97522758, -2.07777926,  1.53375416,  0.62604295,
#          1.54897816,  0.71835006, -0.40104153,  0.80291352, -0.87350258,
#         -1.53165757,  0.61743202, -0.2928486 ,  1.24608425,  0.18045944,
#          1.64904521, -0.96735237, -0.65943387, -1.35733867,  0.43046632,
#         -1.77478933, -0.92190488, -0.10509784,  0.46839275, -0.78045468,
#          1.13177884,  0.03255462, -0.6062102 , -0.66407011,  1.38799868,
#          0.34126183,  1.05757906,  0.40491334, -0.35034229, -0.5371701 ,
#         -1.86731119, -0.48358082, -0.29957044,  0.94052701,  0.9137632 ,
#          0.59742955,  0.82402581, -0.10344754, -1.46469292,  0.12148682,
#         -0.18628682,  1.10338167,  0.74047411,  0.46186809, -0.28485465,
#         -1.25004041, -0.60922279, -0.06704772, -0.99831884,  0.81727408,
#         -0.43225155,  0.54014209,  0.44056441,  1.36889348,  0.48463484,
#          1.61728739, -1.14450434,  1.35032741, -0.24829457,  1.04593641,
#          0.37640256, -0.74246768,  0.71911469,  0.7822724 ,  0.12656151,
#         -1.06320444, -0.36100263, -0.08077789,  0.49228399, -0.59961219,
#          1.46656535, -0.12941065, -1.73243899,  0.60765227,  0.50821464])}

# %%
# SOLUTION
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12, 20))
    
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k])
        plt.title(k)
        
    plt.show()

# %%
graphique(dataset)
